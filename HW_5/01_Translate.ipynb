# %% [markdown]
# # Homework 5: Translation task (German → English)
#
# [Qwen2.5-VL](https://huggingface.co/Qwen/Qwen2.5-VL-7B-Instruct) is a
# vision-language model, but it is also a strong **text** chat model. Here we use
# it **text-only** (no images) to translate the German transcript from
# `00_PrepData` into English.
#
# We translate **segment by segment** so each request stays short and the
# timestamps are preserved — this also scales to clips of any length.
#
# **Sources**
# - Qwen2.5-VL: <https://huggingface.co/Qwen/Qwen2.5-VL-7B-Instruct> ([report](https://arxiv.org/abs/2502.13923))
# - Model class `QwenChat` lives in `src/video_pipeline/qwen_text.py`.

# %%
import json
import shutil
import subprocess
import sys
from pathlib import Path

# Make the vendored `video_pipeline` package importable even if the project
# was not installed (e.g. running `jupyter` outside `uv run`).
SRC = Path.cwd() / "src"
if SRC.exists() and str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

PREPARED = Path("prepared")
PREPARED.mkdir(exist_ok=True)

transcript = json.loads((PREPARED / "transcript.json").read_text(encoding="utf-8"))
print(f"loaded transcript: {len(transcript['segments'])} segments, "
      f"{len(transcript['text'])} chars")
print("\nfirst 300 chars (German):\n", transcript["text"][:300])
# Out:
# loaded transcript: 7 segments, 1555 chars
#
# first 300 chars (German):
#  Nach dem Ende des Zweiten Weltkriegs 1945 beginnt eine neue Form von Krieg. Ein kalter Krieg zwischen den beiden Großmächten USA und der Sowjetunion. Kalt bedeutet, dass nicht geschossen, sondern nur gedroht und aufgerüstet wird. Aber der Konflikt kann jederzeit eskalieren und das macht vielen Mensc

# %% [markdown]
# ## Translate each segment with Qwen2.5-VL
#
# `QwenChat.translate(text, source, target)` wraps a single system+user chat turn.
# We load the model once (`with QwenChat() as qc:`) and reuse it across all
# segments, then it is unloaded and the GPU cache is cleared on exit.

# %%
from video_pipeline.qwen_text import QwenChat

# TODODONE (Exercise 2a): translate every segment from German into English.
translated_segments = []
with QwenChat() as qc:
    for i, seg in enumerate(transcript["segments"], start=1):
        english = qc.translate(seg["text"], source="German", target="English")
        translated_segments.append({**seg, "text": english})
        print(f"[{i}/{len(transcript['segments'])}] {english[:70]}")

english_text = "\n".join(s["text"] for s in translated_segments)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# [1/7] After the end of World War II in 1945, a new form of war begins. A col
# [2/7] United Kingdom and later allied with liberated France and thus formed
# [3/7] Enemy Nazi Germany defeated. But after the victorious powers divided G
# [4/7] having been divided, good cooperation is over. An aggressive competiti
# [5/7] the systems that lasted for 45 years. The Soviet Union and its so-call
# [6/7] The following is a period of East-West détente.
# [7/7] But that is over for 2022 with Russia's attack on Ukraine.

# %% [markdown]
# ## Save a `TranslationResult`
#
# We store the full English text in the project's `TranslationResult` schema so
# the next notebook (and the CLI) can consume it.

# %%
from video_pipeline.models import TranslationResult

result = TranslationResult(
    source_path=str(PREPARED / "transcript.json"),
    source_language="German",
    target_language="English",
    source_text=transcript["text"],
    text=english_text,
)
out = PREPARED / "translation.json"
out.write_text(result.model_dump_json(indent=2), encoding="utf-8")
print("wrote", out, "-", len(english_text), "chars")
# Out:
# wrote prepared/translation.json - 1475 chars

# %%
# German vs English, side by side per segment.
for de, en in zip(transcript["segments"][:6], translated_segments[:6]):
    print(f"[{de['start']:6.1f}s] DE: {de['text']}")
    print(f"          EN: {en['text']}\n")
# Out:
# [   0.1s] DE: Nach dem Ende des Zweiten Weltkriegs 1945 beginnt eine neue Form von Krieg. Ein kalter Krieg zwischen den beiden Großmächten USA und der Sowjetunion. Kalt bedeutet, dass nicht geschossen, sondern nur gedroht und aufgerüstet wird. Aber der Konflikt kann jederzeit eskalieren und das macht vielen Menschen jahrzehntelang Angst. Dabei haben sich die beiden Großmächte doch im Zweiten Weltkrieg erfolgreich mit
#           EN: After the end of World War II in 1945, a new form of war begins. A cold war between the two superpowers, the United States and the Soviet Union. Cold means that shots are not fired but only threats and armaments are increased. But the conflict can escalate at any time, which has made many people afraid for decades. However, these two superpowers had successfully collaborated
#
# [  25.7s] DE: Großbritannien und später mit dem befreiten Frankreich verbündet und so den gemeinsamen
#           EN: United Kingdom and later allied with liberated France and thus formed the common
#
# [  30.4s] DE: Feind Nazi-Deutschland besiegt. Aber nachdem die Siegermächte Deutschland in vier Besatzungszonen
#           EN: Enemy Nazi Germany defeated. But after the victorious powers divided Germany into four occupation zones
#
# [  35.8s] DE: aufgeteilt haben, ist die gute Zusammenarbeit beendet. Es beginnt ein aggressiver Wettstreit
#           EN: having been divided, good cooperation is over. An aggressive competition begins.
#
# [  42.1s] DE: der Systeme, der 45 Jahre andauert. Die Sowjetunion und ihre sogenannten Bruderstaaten im Osten gegen Die USA und die USA-Unternehmen sind in den USA-Unternehmen in den USA-Unternehmen in den USA-Un der sowjetischen Besatzungszone wird 1949 ein eigener Bruderstaat, die DDR. Es geht bei diesem Wettstreit vor allem um die Frage, welches Gesellschaftssystem mächtiger ist. Der Kommunismus und die Planwirtschaft des Ostens oder die Demokratie und der Kapitalismus des Westens. Und natürlich um Macht und Einfluss in der ganzen Welt. Militärisch und technologisch beginnt ein Wettrüsten mit Atomwaffen, Spionage und dem Kampf um die Vorherrschaft im All. Mit der deutschen Wiedervereinigung und dem Ende der Sowjetunion gilt der Kalte Krieg 1991 als beendet.
#           EN: the systems that lasted for 45 years. The Soviet Union and its so-called brother states in the East against the USA and the US companies is in the US companies in the US companies in the US of the Soviet occupation zone becomes a separate brother state, the GDR. This competition is mainly about the question of which social system is stronger. Communism and the planned economy of the East or democracy and capitalism of the West. And of course about power and influence in the entire world. Militarily and technologically begins a race with nuclear weapons, espionage and the struggle for supremacy in space. With the reunification of Germany and the end of the Soviet Union, the Cold War in 1991 is considered to be over.
#
# [  91.2s] DE: Es folgt eine Zeit der Ost-West-Entspannung.
#           EN: The following is a period of East-West détente.

# %% [markdown]
# ---
# **Next:** `02_Summarize_OCR.ipynb` — summarise the English transcript and OCR the
# on-screen text from the video frames.
