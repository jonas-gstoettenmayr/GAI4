# %% [markdown]
# # Variational Autoencoder with 3D Latent Space
#
# Same VAE recipe as `02_VAE_2D.ipynb` but with `z_dim = 3`. Compares against the
# plain AE from `01_FC_Autoencoder_3D.ipynb`.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
bs = 100
train_dataset = datasets.MNIST(root="./data/", train=True, download=True, transform=transforms.ToTensor())
test_dataset = datasets.MNIST(root="./data/", train=False, download=True, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=bs, shuffle=False)
print(f"Train: {len(train_dataset)}, Test: {len(test_dataset)}")
# Out:
# Train: 60000, Test: 10000

# %% [markdown]
# ## 1. Model

# %%
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim1, h_dim2, z_dim):
        super().__init__()
        # encoder part
        self.fc1 = nn.Linear(x_dim, h_dim1)
        self.fc2 = nn.Linear(h_dim1, h_dim2)
        self.fc31 = nn.Linear(h_dim2, z_dim)
        self.fc32 = nn.Linear(h_dim2, z_dim)
        # decoder part
        self.fc4 = nn.Linear(z_dim, h_dim2)
        self.fc5 = nn.Linear(h_dim2, h_dim1)
        self.fc6 = nn.Linear(h_dim1, x_dim)

    def encoder(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        return self.fc31(h), self.fc32(h)  # mu, log_var

    def sampling(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)

    def decoder(self, z):
        h = F.relu(self.fc4(z))
        h = F.relu(self.fc5(h))
        return torch.sigmoid(self.fc6(h))

    def forward(self, x):
        mu, log_var = self.encoder(x.view(-1, 784))
        z = self.sampling(mu, log_var)
        return self.decoder(z), mu, log_var


vae = VAE(x_dim=784, h_dim1=512, h_dim2=256, z_dim=3).to(device)
print(vae)
# Out:
# VAE(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc31): Linear(in_features=256, out_features=3, bias=True)
#   (fc32): Linear(in_features=256, out_features=3, bias=True)
#   (fc4): Linear(in_features=3, out_features=256, bias=True)
#   (fc5): Linear(in_features=256, out_features=512, bias=True)
#   (fc6): Linear(in_features=512, out_features=784, bias=True)
# )

# %% [markdown]
# ## 2. Loss and Optimizer

# %%
optimizer = optim.Adam(vae.parameters())

def loss_function(recon_x, x, mu, log_var):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction="sum")
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    return BCE + KLD

# %% [markdown]
# ## 3. Training

# %%
def train(epoch):
    vae.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()

        recon_batch, mu, log_var = vae(data)
        loss = loss_function(recon_batch, data, mu, log_var)

        loss.backward()
        train_loss += loss.item()
        optimizer.step()

        if batch_idx % 100 == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print("====> Epoch: {} Average loss: {:.4f}".format(epoch, train_loss / len(train_loader.dataset)))


def test():
    vae.eval()
    test_loss = 0
    with torch.no_grad():
        for data, _ in test_loader:
            data = data.to(device)
            recon, mu, log_var = vae(data)
            test_loss += loss_function(recon, data, mu, log_var).item()
    test_loss /= len(test_loader.dataset)
    print("====> Test set loss: {:.4f}".format(test_loss))

# %%
for epoch in range(1, 31):
    train(epoch)
    test()

torch.save(vae.state_dict(), "fc_vae_3d.pth")
print("Saved fc_vae_3d.pth")
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 131.201875
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 134.158164
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 133.882285
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 133.624004
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 131.000020
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 129.785107
# ====> Epoch: 1 Average loss: 129.7439
# ====> Test set loss: 130.6766
# Train Epoch: 2 [0/60000 (0%)]	Loss: 129.991836
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 129.082285
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 122.784043
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 124.720361
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 134.166836
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 126.433574
# ====> Epoch: 2 Average loss: 129.2012
# ====> Test set loss: 130.2540
# Train Epoch: 3 [0/60000 (0%)]	Loss: 127.592354
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 131.956504
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 130.223379
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 129.488926
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 131.835889
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 121.826514
# ====> Epoch: 3 Average loss: 128.6902
# ====> Test set loss: 130.1218
# Train Epoch: 4 [0/60000 (0%)]	Loss: 121.314248
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 133.069600
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 133.932627
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 129.819395
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 130.503643
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 125.825078
# ====> Epoch: 4 Average loss: 128.3555
# ====> Test set loss: 129.8122
# Train Epoch: 5 [0/60000 (0%)]	Loss: 127.001191
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 128.468418
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 123.434912
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 133.075967
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 133.643467
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 128.023936
# ====> Epoch: 5 Average loss: 127.9398
# ====> Test set loss: 129.6958
# Train Epoch: 6 [0/60000 (0%)]	Loss: 127.439307
# Train Epoch: 6 [10000/60000 (17%)]	Loss: 126.383164
# Train Epoch: 6 [20000/60000 (33%)]	Loss: 121.830313
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 122.925098
# Train Epoch: 6 [40000/60000 (67%)]	Loss: 125.619297
# Train Epoch: 6 [50000/60000 (83%)]	Loss: 123.745479
# ====> Epoch: 6 Average loss: 127.6380
# ====> Test set loss: 129.6675
# Train Epoch: 7 [0/60000 (0%)]	Loss: 125.389648
# Train Epoch: 7 [10000/60000 (17%)]	Loss: 126.515146
# Train Epoch: 7 [20000/60000 (33%)]	Loss: 122.978789
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 124.121904
# Train Epoch: 7 [40000/60000 (67%)]	Loss: 128.942959
# Train Epoch: 7 [50000/60000 (83%)]	Loss: 126.971992
# ====> Epoch: 7 Average loss: 127.2764
# ====> Test set loss: 129.4024
# Train Epoch: 8 [0/60000 (0%)]	Loss: 130.063477
# Train Epoch: 8 [10000/60000 (17%)]	Loss: 121.257979
# Train Epoch: 8 [20000/60000 (33%)]	Loss: 130.909258
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 126.197959
# Train Epoch: 8 [40000/60000 (67%)]	Loss: 126.392314
# Train Epoch: 8 [50000/60000 (83%)]	Loss: 120.670186
# ====> Epoch: 8 Average loss: 127.0366
# ====> Test set loss: 129.1703
# Train Epoch: 9 [0/60000 (0%)]	Loss: 132.265977
# Train Epoch: 9 [10000/60000 (17%)]	Loss: 122.796143
# Train Epoch: 9 [20000/60000 (33%)]	Loss: 124.582998
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 128.349287
# Train Epoch: 9 [40000/60000 (67%)]	Loss: 125.587842
# Train Epoch: 9 [50000/60000 (83%)]	Loss: 128.760176
# ====> Epoch: 9 Average loss: 126.7883
# ====> Test set loss: 129.0023
# Train Epoch: 10 [0/60000 (0%)]	Loss: 127.027539
# Train Epoch: 10 [10000/60000 (17%)]	Loss: 138.148066
# Train Epoch: 10 [20000/60000 (33%)]	Loss: 132.408936
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 128.709873
# Train Epoch: 10 [40000/60000 (67%)]	Loss: 128.006152
# Train Epoch: 10 [50000/60000 (83%)]	Loss: 118.542695
# ====> Epoch: 10 Average loss: 126.5099
# ====> Test set loss: 128.7023
# Train Epoch: 11 [0/60000 (0%)]	Loss: 130.560430
# Train Epoch: 11 [10000/60000 (17%)]	Loss: 129.840439
# Train Epoch: 11 [20000/60000 (33%)]	Loss: 126.784551
# Train Epoch: 11 [30000/60000 (50%)]	Loss: 124.744160
# Train Epoch: 11 [40000/60000 (67%)]	Loss: 123.432832
# Train Epoch: 11 [50000/60000 (83%)]	Loss: 129.986025
# ====> Epoch: 11 Average loss: 126.2701
# ====> Test set loss: 128.9271
# Train Epoch: 12 [0/60000 (0%)]	Loss: 122.049326
# Train Epoch: 12 [10000/60000 (17%)]	Loss: 121.545498
# Train Epoch: 12 [20000/60000 (33%)]	Loss: 126.220264
# Train Epoch: 12 [30000/60000 (50%)]	Loss: 125.438789
# Train Epoch: 12 [40000/60000 (67%)]	Loss: 129.314053
# Train Epoch: 12 [50000/60000 (83%)]	Loss: 127.487793
# ====> Epoch: 12 Average loss: 126.0485
# ====> Test set loss: 128.9440
# Train Epoch: 13 [0/60000 (0%)]	Loss: 130.180156
# Train Epoch: 13 [10000/60000 (17%)]	Loss: 128.536416
# Train Epoch: 13 [20000/60000 (33%)]	Loss: 130.154609
# Train Epoch: 13 [30000/60000 (50%)]	Loss: 127.853477
# Train Epoch: 13 [40000/60000 (67%)]	Loss: 124.554824
# Train Epoch: 13 [50000/60000 (83%)]	Loss: 120.421328
# ====> Epoch: 13 Average loss: 125.8881
# ====> Test set loss: 128.6634
# Train Epoch: 14 [0/60000 (0%)]	Loss: 128.076602
# Train Epoch: 14 [10000/60000 (17%)]	Loss: 119.900869
# Train Epoch: 14 [20000/60000 (33%)]	Loss: 127.368613
# Train Epoch: 14 [30000/60000 (50%)]	Loss: 124.291699
# Train Epoch: 14 [40000/60000 (67%)]	Loss: 130.310127
# Train Epoch: 14 [50000/60000 (83%)]	Loss: 117.146094
# ====> Epoch: 14 Average loss: 125.6248
# ====> Test set loss: 128.7214
# Train Epoch: 15 [0/60000 (0%)]	Loss: 125.585508
# Train Epoch: 15 [10000/60000 (17%)]	Loss: 126.483135
# Train Epoch: 15 [20000/60000 (33%)]	Loss: 120.322119
# Train Epoch: 15 [30000/60000 (50%)]	Loss: 124.931182
# Train Epoch: 15 [40000/60000 (67%)]	Loss: 124.203232
# Train Epoch: 15 [50000/60000 (83%)]	Loss: 127.990586
# ====> Epoch: 15 Average loss: 125.4389
# ====> Test set loss: 128.7383
# Train Epoch: 16 [0/60000 (0%)]	Loss: 120.387793
# Train Epoch: 16 [10000/60000 (17%)]	Loss: 126.013740
# Train Epoch: 16 [20000/60000 (33%)]	Loss: 131.947920
# Train Epoch: 16 [30000/60000 (50%)]	Loss: 129.604434
# Train Epoch: 16 [40000/60000 (67%)]	Loss: 116.559141
# Train Epoch: 16 [50000/60000 (83%)]	Loss: 125.739424
# ====> Epoch: 16 Average loss: 125.3097
# ====> Test set loss: 128.5004
# Train Epoch: 17 [0/60000 (0%)]	Loss: 127.495928
# Train Epoch: 17 [10000/60000 (17%)]	Loss: 119.363457
# Train Epoch: 17 [20000/60000 (33%)]	Loss: 125.659512
# Train Epoch: 17 [30000/60000 (50%)]	Loss: 128.111777
# Train Epoch: 17 [40000/60000 (67%)]	Loss: 123.420557
# Train Epoch: 17 [50000/60000 (83%)]	Loss: 124.332676
# ====> Epoch: 17 Average loss: 125.2106
# ====> Test set loss: 128.6419
# Train Epoch: 18 [0/60000 (0%)]	Loss: 131.890234
# Train Epoch: 18 [10000/60000 (17%)]	Loss: 113.222393
# Train Epoch: 18 [20000/60000 (33%)]	Loss: 125.688613
# Train Epoch: 18 [30000/60000 (50%)]	Loss: 121.503652
# Train Epoch: 18 [40000/60000 (67%)]	Loss: 126.901025
# Train Epoch: 18 [50000/60000 (83%)]	Loss: 121.186572
# ====> Epoch: 18 Average loss: 125.0072
# ====> Test set loss: 128.4520
# Train Epoch: 19 [0/60000 (0%)]	Loss: 125.997383
# Train Epoch: 19 [10000/60000 (17%)]	Loss: 127.369854
# Train Epoch: 19 [20000/60000 (33%)]	Loss: 124.686289
# Train Epoch: 19 [30000/60000 (50%)]	Loss: 130.161514
# Train Epoch: 19 [40000/60000 (67%)]	Loss: 120.426221
# Train Epoch: 19 [50000/60000 (83%)]	Loss: 126.970713
# ====> Epoch: 19 Average loss: 124.8438
# ====> Test set loss: 128.3158
# Train Epoch: 20 [0/60000 (0%)]	Loss: 120.390850
# Train Epoch: 20 [10000/60000 (17%)]	Loss: 124.487383
# Train Epoch: 20 [20000/60000 (33%)]	Loss: 118.641133
# Train Epoch: 20 [30000/60000 (50%)]	Loss: 119.276191
# Train Epoch: 20 [40000/60000 (67%)]	Loss: 129.063535
# Train Epoch: 20 [50000/60000 (83%)]	Loss: 121.691729
# ====> Epoch: 20 Average loss: 124.7165
# ====> Test set loss: 128.3152
# Train Epoch: 21 [0/60000 (0%)]	Loss: 129.685674
# Train Epoch: 21 [10000/60000 (17%)]	Loss: 119.245752
# Train Epoch: 21 [20000/60000 (33%)]	Loss: 122.969707
# Train Epoch: 21 [30000/60000 (50%)]	Loss: 130.157285
# Train Epoch: 21 [40000/60000 (67%)]	Loss: 127.900850
# Train Epoch: 21 [50000/60000 (83%)]	Loss: 123.188350
# ====> Epoch: 21 Average loss: 124.5570
# ====> Test set loss: 128.3333
# Train Epoch: 22 [0/60000 (0%)]	Loss: 124.358086
# Train Epoch: 22 [10000/60000 (17%)]	Loss: 129.769639
# Train Epoch: 22 [20000/60000 (33%)]	Loss: 127.564766
# Train Epoch: 22 [30000/60000 (50%)]	Loss: 122.349023
# Train Epoch: 22 [40000/60000 (67%)]	Loss: 126.647842
# Train Epoch: 22 [50000/60000 (83%)]	Loss: 125.249736
# ====> Epoch: 22 Average loss: 124.4460
# ====> Test set loss: 128.2371
# Train Epoch: 23 [0/60000 (0%)]	Loss: 128.605566
# Train Epoch: 23 [10000/60000 (17%)]	Loss: 119.359316
# Train Epoch: 23 [20000/60000 (33%)]	Loss: 127.271670
# Train Epoch: 23 [30000/60000 (50%)]	Loss: 127.056201
# Train Epoch: 23 [40000/60000 (67%)]	Loss: 130.220000
# Train Epoch: 23 [50000/60000 (83%)]	Loss: 127.342715
# ====> Epoch: 23 Average loss: 124.3104
# ====> Test set loss: 128.4032
# Train Epoch: 24 [0/60000 (0%)]	Loss: 121.449209
# Train Epoch: 24 [10000/60000 (17%)]	Loss: 121.382578
# Train Epoch: 24 [20000/60000 (33%)]	Loss: 126.738730
# Train Epoch: 24 [30000/60000 (50%)]	Loss: 116.612305
# Train Epoch: 24 [40000/60000 (67%)]	Loss: 118.393809
# Train Epoch: 24 [50000/60000 (83%)]	Loss: 122.100166
# ====> Epoch: 24 Average loss: 124.1978
# ====> Test set loss: 127.9496
# Train Epoch: 25 [0/60000 (0%)]	Loss: 129.550000
# Train Epoch: 25 [10000/60000 (17%)]	Loss: 120.112334
# Train Epoch: 25 [20000/60000 (33%)]	Loss: 134.230273
# Train Epoch: 25 [30000/60000 (50%)]	Loss: 124.475938
# Train Epoch: 25 [40000/60000 (67%)]	Loss: 120.156152
# Train Epoch: 25 [50000/60000 (83%)]	Loss: 127.051826
# ====> Epoch: 25 Average loss: 124.0910
# ====> Test set loss: 128.0101
# Train Epoch: 26 [0/60000 (0%)]	Loss: 124.164131
# Train Epoch: 26 [10000/60000 (17%)]	Loss: 126.703477
# Train Epoch: 26 [20000/60000 (33%)]	Loss: 120.604971
# Train Epoch: 26 [30000/60000 (50%)]	Loss: 114.733594
# Train Epoch: 26 [40000/60000 (67%)]	Loss: 125.304346
# Train Epoch: 26 [50000/60000 (83%)]	Loss: 122.268799
# ====> Epoch: 26 Average loss: 123.9666
# ====> Test set loss: 128.3075
# Train Epoch: 27 [0/60000 (0%)]	Loss: 122.540732
# Train Epoch: 27 [10000/60000 (17%)]	Loss: 125.114180
# Train Epoch: 27 [20000/60000 (33%)]	Loss: 123.712939
# Train Epoch: 27 [30000/60000 (50%)]	Loss: 122.700469
# Train Epoch: 27 [40000/60000 (67%)]	Loss: 130.492979
# Train Epoch: 27 [50000/60000 (83%)]	Loss: 126.870039
# ====> Epoch: 27 Average loss: 123.8355
# ====> Test set loss: 128.3515
# Train Epoch: 28 [0/60000 (0%)]	Loss: 123.566172
# Train Epoch: 28 [10000/60000 (17%)]	Loss: 116.563145
# Train Epoch: 28 [20000/60000 (33%)]	Loss: 123.540508
# Train Epoch: 28 [30000/60000 (50%)]	Loss: 119.741016
# Train Epoch: 28 [40000/60000 (67%)]	Loss: 122.190615
# Train Epoch: 28 [50000/60000 (83%)]	Loss: 116.866338
# ====> Epoch: 28 Average loss: 123.7718
# ====> Test set loss: 127.8815
# Train Epoch: 29 [0/60000 (0%)]	Loss: 121.871553
# Train Epoch: 29 [10000/60000 (17%)]	Loss: 123.619170
# Train Epoch: 29 [20000/60000 (33%)]	Loss: 127.583213
# Train Epoch: 29 [30000/60000 (50%)]	Loss: 122.553535
# Train Epoch: 29 [40000/60000 (67%)]	Loss: 123.101709
# Train Epoch: 29 [50000/60000 (83%)]	Loss: 126.169160
# ====> Epoch: 29 Average loss: 123.6666
# ====> Test set loss: 128.1319
# Train Epoch: 30 [0/60000 (0%)]	Loss: 124.769209
# Train Epoch: 30 [10000/60000 (17%)]	Loss: 123.122373
# Train Epoch: 30 [20000/60000 (33%)]	Loss: 121.636299
# Train Epoch: 30 [30000/60000 (50%)]	Loss: 122.547832
# Train Epoch: 30 [40000/60000 (67%)]	Loss: 121.449180
# Train Epoch: 30 [50000/60000 (83%)]	Loss: 128.155566
# ====> Epoch: 30 Average loss: 123.6307
# ====> Test set loss: 128.1336
# Saved fc_vae_3d.pth

# %% [markdown]
# ## 4. Reconstruction Quality

# %%
vae.eval()
data, _ = next(iter(test_loader))
data = data[:10].to(device)
with torch.no_grad():
    recon, _, _ = vae(data)
recon = recon.view(-1, 1, 28, 28)

fig, axes = plt.subplots(2, 10, figsize=(15, 4))
for i in range(10):
    axes[0, i].imshow(data[i].cpu().squeeze(), cmap="gray"); axes[0, i].axis("off")
    axes[1, i].imshow(recon[i].cpu().squeeze(), cmap="gray"); axes[1, i].axis("off")

plt.suptitle("VAE reconstruction with 3-D bottleneck", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. The 3D Latent Space
#
# Encode the entire test set and plot the encoder means $\mu$ in 3D.

# %%
all_mu, all_labels = [], []
with torch.no_grad():
    for data, labels in test_loader:
        mu, _ = vae.encoder(data.to(device).view(-1, 784))
        all_mu.append(mu.cpu()); all_labels.append(labels)
all_mu = torch.cat(all_mu).numpy()
all_labels = torch.cat(all_labels).numpy()

for i in range(3):
    print(f"mu_{i+1}: range [{all_mu[:, i].min():.2f}, {all_mu[:, i].max():.2f}], "
          f"mean={all_mu[:, i].mean():.2f}, std={all_mu[:, i].std():.2f}")
# Out:
# mu_1: range [-4.84, 5.30], mean=0.02, std=0.97
# mu_2: range [-4.09, 3.64], mean=-0.02, std=1.04
# mu_3: range [-4.79, 4.02], mean=-0.05, std=1.01

# %% [markdown]
# ## 6. Side-by-Side: AE vs VAE Latent Space
#
# Load the AE latents from `01_FC_Autoencoder_3D.ipynb` and plot both clouds with
# the same axis limits so the difference in scale and shape is obvious.

# %%
ae_data = np.load("latents_ae_3d.npz")
ae_z = ae_data["z"]
ae_labels = ae_data["labels"]

all_pts = np.vstack([ae_z, all_mu])
lo, hi = all_pts.min(), all_pts.max()

fig = plt.figure(figsize=(15, 7))
for k, (pts, labels, title) in enumerate(
    [(ae_z, ae_labels, "AE"), (all_mu, all_labels, "VAE")]
):
    ax = fig.add_subplot(1, 2, k + 1, projection="3d")
    sc = ax.scatter(pts[:, 0], pts[:, 1], pts[:, 2],
                    c=labels, cmap="tab10", s=3, alpha=0.6)
    ax.set_xlim(lo, hi); ax.set_ylim(lo, hi); ax.set_zlim(lo, hi)
    ax.set_xlabel("$z_1$"); ax.set_ylabel("$z_2$"); ax.set_zlabel("$z_3$")
    ax.set_title(f"{title} latent space  (range x: [{pts[:,0].min():.1f}, {pts[:,0].max():.1f}])")
fig.suptitle("AE (no constraint) vs VAE (KL pulls toward unit Gaussian) — same axes", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Sampling: $z \sim \mathcal{N}(0, I)$
#
# Run the same Gaussian samples through both decoders.

# %%
# Reload the AE for the side-by-side decoder comparison
class FCAutoencoder(nn.Module):
    def __init__(self, latent_dim=3):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 256), nn.ReLU(),
            nn.Linear(256, 64), nn.ReLU(),
            nn.Linear(64, latent_dim),
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.ReLU(),
            nn.Linear(64, 256), nn.ReLU(),
            nn.Linear(256, 28 * 28), nn.Sigmoid(),
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z).view(-1, 1, 28, 28), z

ae = FCAutoencoder(3).to(device)
ae.load_state_dict(torch.load("fc_autoencoder_3d.pth", map_location=device))
ae.eval()

torch.manual_seed(0)
N = 16
z = torch.randn(N, 3, device=device)
with torch.no_grad():
    ae_samples = ae.decoder(z).view(-1, 28, 28).cpu()
    vae_samples = vae.decoder(z).view(-1, 28, 28).cpu()

fig, axes = plt.subplots(2, N, figsize=(1.4 * N, 3))
for j in range(N):
    axes[0, j].imshow(ae_samples[j], cmap="gray", vmin=0, vmax=1); axes[0, j].axis("off")
    axes[1, j].imshow(vae_samples[j], cmap="gray", vmin=0, vmax=1); axes[1, j].axis("off")

fig.suptitle("Same $z \\sim \\mathcal{N}(0, I)$ through both decoders", fontsize=12)
plt.tight_layout()
plt.show()
